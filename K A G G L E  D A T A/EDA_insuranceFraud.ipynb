# %% [markdown]
# # Building Machine Learning Pipelines: Data Analysis Phase

# %% [markdown]
# # All the Lifecycle In A Data Science Projects
#
# 1. Data Analysis
# 2. Feature Engineering
# 3. Feature Selection
# 4. Model Building
# 5. Model Deployment

# %%
## Data Analysis Phase
## MAin aim is to understand more about the data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
## Display all the columns of the dataframe

pd.pandas.set_option('display.max_columns',None)

# %%
dataset = pd.read_csv(r'C:\EXCELR\KAGGLE\INSURANCE\insuranceFraud.csv')

                      
## print shape of dataset with rows and columns
dataset.shape
# Out:
# (1000, 39)

# %%
dataset.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       10/17/2014           OH
# 1                 228   42         342868        6/27/2006           IN
# 2                 134   29         687698         9/6/2000           OH
# 3                 256   41         227811        5/25/1990           IL
# 4                 228   44         367455         6/6/2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %%
dataset["Fraud_0_1"] = 0
dataset.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       10/17/2014           OH
# 1                 228   42         342868        6/27/2006           IN
# 2                 134   29         687698         9/6/2000           OH
# 3                 256   41         227811        5/25/1990           IL
# 4                 228   44         367455         6/6/2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %%
dataset.shape
# Out:
# (1000, 40)

# %%
dataset.drop(['fraud_reported'], axis=1, inplace=True)
dataset.shape
# Out:
# (1000, 39)

# %% [markdown]
# # In Data Analysis We will Analyze To Find out the below stuff
#
# 1. Missing Values
# 2. All The Numerical Variables
# 3. Distribution of the Numerical Variables
# 4. Categorical Variables
# 5. Cardinality of Categorical Variables
# 6. Outliers
# 7. Relationship between independent and dependent feature(SalePrice)

# %% [markdown]
# # Missing Values

# %%
features_with_na=[feature for feature in dataset.columns if dataset[feature].isnull().sum()>1]
features_with_na
# Out:
# []

# %%
sns.heatmap(dataset.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# THERE ARE NO MISSIG VAUES PROVIDED BY THE CLIENT DATA

# %% [markdown]
# # Numerical Variables

# %%
numerical_features=[feature for feature in dataset.columns if dataset[feature].dtypes!='O']
numerical_features
# Out:
# ['months_as_customer',
#  'age',
#  'policy_number',
#  'policy_deductable',
#  'policy_annual_premium',
#  'umbrella_limit',
#  'insured_zip',
#  'capital-gains',
#  'capital-loss',
#  'incident_hour_of_the_day',
#  'number_of_vehicles_involved',
#  'bodily_injuries',
#  'witnesses',
#  'total_claim_amount',
#  'injury_claim',
#  'property_claim',
#  'vehicle_claim',
#  'auto_year',
#  'Fraud_0_1']

# %%
dataset[numerical_features].head()
# Out:
#    months_as_customer  age  policy_number  policy_deductable  \
# 0                 328   48         521585               1000
# 1                 228   42         342868               2000
# 2                 134   29         687698               2000
# 3                 256   41         227811               2000
# 4                 228   44         367455               1000
#
#    policy_annual_premium  umbrella_limit  insured_zip  capital-gains  \
# 0                1406.91               0       466132          53300
# 1                1197.22         5000000       468176              0
# 2                1413.14         5000000       430632          35100
# 3                1415.74         6000000       608117          48900
# 4                1583.91         6000000       610706          66000
#
#    capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0             0                         5                            1
# ...

# %% [markdown]
# # Temporal Variables(Eg: Datetime Variables)

# %%
year_feature = [feature for feature in numerical_features if 'auto_year' in feature]

year_feature
# Out:
# ['auto_year']

# %%
# let's explore the content of these year variables
for feature in year_feature:
    print(feature, dataset[feature].unique())
# Out:
# auto_year [2004 2007 2014 2009 2003 2012 2015 1996 2002 2006 2000 2010 1999 2011
#  2005 2008 1995 2001 1998 1997 2013]

# %%
for feature in year_feature:
    data=dataset.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %% [markdown]
# *********** WE COULD SEE I THE HISTOGRAM FOR THE VARIABLE "auto_year" THERE IS SKEWNESS PROBLEM WE COULD NOT DETERMINE IT
# IT SHOULD GO THROUGH TRANSFORMATION ****************

# %%
discrete_feature=[feature for feature in numerical_features if len(dataset[feature].unique())<25 and feature not in year_feature+['Id']]

print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 7

# %%
dataset[discrete_feature].head()
# Out:
#    policy_deductable  umbrella_limit  incident_hour_of_the_day  \
# 0               1000               0                         5
# 1               2000         5000000                         8
# 2               2000         5000000                         7
# 3               2000         6000000                         5
# 4               1000         6000000                        20
#
#    number_of_vehicles_involved  bodily_injuries  witnesses  Fraud_0_1
# 0                            1                1          2          0
# 1                            1                0          0          0
# 2                            3                2          3          0
# 3                            1                1          2          0
# 4                            1                0          1          0

# %% [markdown]
# # Continuous Variable

# %%
continuous_feature=[feature for feature in numerical_features if feature not in discrete_feature+year_feature]

print("Continuous feature Count {}".format(len(continuous_feature)))
# Out:
# Continuous feature Count 11

# %%
dataset[continuous_feature].head()
# Out:
#    months_as_customer  age  policy_number  policy_annual_premium  insured_zip  \
# 0                 328   48         521585                1406.91       466132
# 1                 228   42         342868                1197.22       468176
# 2                 134   29         687698                1413.14       430632
# 3                 256   41         227811                1415.74       608117
# 4                 228   44         367455                1583.91       610706
#
#    capital-gains  capital-loss  total_claim_amount  injury_claim  \
# 0          53300             0               71610          6510
# 1              0             0                5070           780
# 2          35100             0               34650          7700
# 3          48900        -62400               63400          6340
# 4          66000        -46000                6500          1300
#
#    property_claim  vehicle_claim
# 0           13020          52080
# 1             780           3510
# ...

# %%
dataset[continuous_feature].hist(figsize=(15,15), xrot=-45, bins=10) ## Display the labels rotated by 45 degress

# Clear the text "residue"
plt.show()

# %%
for feature in continuous_feature:
    data=dataset.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data[feature].hist(figsize=(3,3), xrot=-45, bins=10)  ## Display the labels rotated by 45 degress
        # Clear the text "residue"
        plt.show()

# %% [markdown]
# # Handling Outliers

# %%
for feature in continuous_feature:
    data=dataset.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %%
import joypy

# %%
fig, axes = joypy.joyplot(data,
                         column = ['incident_hour_of_the_day','number_of_vehicles_involved', 'witnesses'],
                         by = 'incident_city',
                         ylim = 'own',
                         figsize = (20, 10),
                         alpha = 0.5, 
                         legend = True)

plt.title('Incident hour, No. of vehicles, witnesses vs Incident City', fontsize = 20)
plt.show()

# %% [markdown]
# # DATA CLEANING IN EDA

# %%
# let's check whether the data has any null values or not.

# but there are '?' in the datset which we have to remove by NaN Values
dataset= dataset.replace('?',np.NaN)

dataset.isnull().any()
# Out:
# months_as_customer             False
# age                            False
# policy_number                  False
# policy_bind_date               False
# policy_state                   False
# policy_csl                     False
# policy_deductable              False
# policy_annual_premium          False
# umbrella_limit                 False
# insured_zip                    False
# insured_sex                    False
# insured_education_level        False
# insured_occupation             False
# insured_hobbies                False
# insured_relationship           False
# capital-gains                  False
# capital-loss                   False
# incident_date                  False
# incident_type                  False
# collision_type                  True
# incident_severity              False
# authorities_contacted          False
# incident_state                 False
# incident_city                  False
# incident_location              False
# ...

# %%
# we will replace the '?' by the most common collision type as we are unaware of the type.
data['collision_type'].fillna(data['collision_type'].mode()[0], inplace = True)

# It may be the case that there are no responses for property damage then we might take it as No property damage.
data['property_damage'].fillna('NO', inplace = True)

# again, if there are no responses fpr police report available then we might take it as No report available
data['police_report_available'].fillna('NO', inplace = True)

data.isnull().any().any()
# Out:
# False

# %% [markdown]
# ************* IN THE ABOVE COLUMNS LIKE "collision_type" WE WENT THROGH MODE OPTIONS BASED ON THE DOMAIN EXPERTS
# SUGGESTION MAJOR THINGS FILLED BY MODE ITSELF *************

# %% [markdown]
# ************ AND FOR THE "property_damage" AND "police_report_available" WE FILLED THE DATA AS "NO"
# BASED ON SEEING OTHER COLUMNS AS WEELL LIKE REPORT IS AVAILABLE OR NOT
# BECASE OF THIS WE FILLED "NO" SINCE IT WAS NOT AVAILABLE ************

# %% [markdown]
# # DATA VISUALIZATION

# %%
# plotting a scatter plot

fig = px.scatter(data, x = 'total_claim_amount', y = 'policy_annual_premium', color = 'insured_sex',
                marginal_x = 'rug', marginal_y = 'histogram')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-beeb7f3ece73> in <module>()
#       1 # plotting a scatter plot
#       2
# ----> 3 fig = px.scatter(data, x = 'total_claim_amount', y = 'policy_annual_premium', color = 'insured_sex',
#       4                 marginal_x = 'rug', marginal_y = 'histogram')
#       5 fig.show()
#
# NameError: name 'px' is not defined

# %%
print(dataset['total_claim_amount'].dtypes)
print(dataset['policy_annual_premium'].dtypes)
# Out:
# int64
# float64

# %% [markdown]
# *** Lets Find the realtionship between total_claim_amount and Sale policy_annual_premium****

# %%
data=dataset.copy()
plt.scatter(data['total_claim_amount'],data['policy_annual_premium'])
plt.xlabel('total_claim_amount(int64)')
plt.ylabel('policy_annual_premium(float64)')
plt.show()

# %% [markdown]
# ***OBSERVATIONS FROM ABOVE:***
#     1. we could see that for 400 and 600 upto 1800rs the total amount is claimed below 10k in X-AXIS if we see.
#     2. And also if we see policies like 600 to 1800 2000 rs also have been paid like 1 lakh and 1.2 lakh
#     2. SUSPECTION: Reason might be new customers or incident damage type might be less according to the policies

# %%
#data['total_claim_amount'].hist(bins=25)
#plt.xlabel('total_claim_amount')
#plt.ylabel("count")
#plt.title(feature)
#plt.show()

# %% [markdown]
# **** LETS SEE HOW THEY HAVE PROVIDED THE AMOUNT BASED ON THE CUSTOMER MONTHS VS CLAIMED AMOUNT ****

# %%
data=dataset.copy()
plt.scatter(data['total_claim_amount'],data['months_as_customer'])
plt.xlabel('total_claim_amount(int64)')
plt.ylabel('months_as_customer(int)')
plt.show()

# %% [markdown]
# ***OBSERVATIONS FROM ABOVE:***
#
#     1. THEY HAVE GIVEN BELOW 20K AMOUNT AS CLAIMED FOR THE NEW CUSTOMER ALSO TO THE OLD CUSTOMERS SAME MAY BE REASON AGAIN
#        INCIDENT DAMAGE BASED ON
#     2. and customer who are old and they have updated the policies and claimed amount like 80k 1 Lakh and above

# %% [markdown]
# **** LETS SEE HOW THE CUSTOER HAVE MADE ANUUAL PREMIUM POLICIES LIKE
# OLD CUSTOMER FROM MANY MONTHS EXISTING WHICH POLICIES THEY HAVE FOUND
# AND NEW CUSTOMER WHICH POLICIES THEY HAVE TAKEN ****

# %%
data=dataset.copy()
plt.scatter(data['months_as_customer'],data['policy_annual_premium'])
plt.xlabel('months_as_customer(int)')
plt.ylabel('policy_annual_premium(int64)')
plt.show()

# %%
data['months_as_customer'].corr(data['policy_annual_premium'])
# Out:
# 0.005017684448634776

# %% [markdown]
# ***OBSERVATIONS FROM ABOVE:***
#     1. customers new are also have made less as well as more premium chages for annually it is normal

# %% [markdown]
# # LETS SEE SEX WISE HOW THEY CLAIMED AMOUNT

# %%
data=dataset.copy()
data.groupby('insured_sex')['total_claim_amount'].median().plot.bar()
plt.xlabel('insured_sex')
plt.ylabel('total_claim_amount')
plt.title('WHICH SEX HAS MORE CLAIM AMOUNT')
plt.show()

# %% [markdown]
# ***OBSERVATION FROM ABOVE: ***
#     1. THERE IS LITTLE DIFFERENCE IN THE AMOUNT CLAIMED BY SEX LIKE MALE HAS CLAIMED MORE THAN FEMALE

# %%
data=dataset.copy()
data.groupby('insured_sex')['policy_annual_premium'].median().plot.bar()
plt.xlabel('insured_sex')
plt.ylabel('policy_annual_premium')
plt.title('WHICH SEX HAS MORE policy_annual_premium AMOUNT')
plt.show()

# %% [markdown]
# ****OBSERVATION FROM ABOVE:***
#
# 1. THERE IS LITTLE DIFFERENCE IN THE AMOUNT POLICY PREMIUM BY SEX LIKE MALE HAS CLAIMED MORE THAN FEMALE

# %%
data=dataset.copy()
data.groupby('incident_type')['total_claim_amount'].median().plot.bar()
plt.xlabel('incident_type')
plt.ylabel('total_claim_amount')
plt.title('WHICH incident_type HAS MORE total_claim_amount AMOUNT')
plt.show()

# %% [markdown]
# ***OBSERVTION FROM ABOVE:***
#     1. MULTI VEHICLE AND VEHICLE COLLISION HAS CLAIMED MORE AMOUNT LIKE 60 K
#     2. PARKED CAR AND VEHICLE THEFT HAVE LESS AMONT CAIMED

# %% [markdown]
# *** Q. how to increase barplot size in python seaborn?  ***
#
#
# https://kite.com/python/answers/how-to-change-the-seaborn-plot-figure-size-in-python#:~:text=Set%20the%20figsize%20argument%20in,pyplot.&text=subplots(figsize%3DNone)%20with,to%20change%20the%20figure%20size.

# %% [markdown]
# *** Q. HOW TO CHECK 3 VARIABLE IN PANDAS VISUALIZATION ***

# %%
fig_dims = (8, 6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x='incident_type', y='total_claim_amount', hue='incident_severity', saturation=2.5, ax=ax, data=dataset)

# %% [markdown]
# ***OBSERVATION FROM ABOVE***
#
#     1. for the "single vehicle collision" also if it is major/minor/total damage nearly 60 to 70k has been total amount  claimed
#     2. for the "multi vehicle collision" also if it is major/minor/total damage nearly 60 to 70k has been total amount claimed
#     3. for the "vehicle theft" minor damage/trivial damage amount like below 10k has been claimed
#     4. for the "parkded car again " minor damage/trivial damage amount like below 10k has been claimed

# %%
fig_dims = (8, 6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x='incident_type', y='injury_claim', hue='incident_severity', saturation=2.5, ax=ax, data=dataset)

# %%
fig_dims = (8, 6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x='bodily_injuries', y='injury_claim', hue='incident_severity', saturation=2.5, ax=ax, data=dataset)

# %%
fig_dims = (8, 6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x='incident_type', y='property_claim', hue='incident_severity', saturation=2.5, ax=ax, data=dataset)

# %%
fig_dims = (8, 6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x='incident_severity', y='vehicle_claim', hue='collision_type', saturation=2.5, ax=ax, data=dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ee0d48b1b8e9> in <module>()
#       1 fig_dims = (8, 6)
# ----> 2 fig, ax = plt.subplots(figsize=fig_dims)
#       3 sns.barplot(x='incident_severity', y='vehicle_claim', hue='collision_type', saturation=2.5, ax=ax, data=dataset)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ***OBSERVATIONS FROM ABOVE:***
#     1. AMONG INCIDENTS SEVERITY FOR MAJOR, MINOR, TOTALLOSS, TRIVIAL DAMAGE
#        FOR FRONT AND SIDE COLLISION WE HAVE CLAIMED THE MORE AMOUNT UPTO 48K
#     2. FOR REAR IT IS LESS AMOUNT

# %% [markdown]
# ***Incident Type vs Vehicle Claim AND PROPERTY DAMAGED OR NOT***

# %%
fig_dims = (8, 6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x='incident_severity', y='vehicle_claim', hue='property_damage', saturation=2.5, ax=ax, data=dataset)

# %%
OBSERVATIONS FROM ABOVE:
    1.

# %%
data=dataset.copy()
data.groupby('incident_type')['vehicle_claim'].median().plot.bar()
plt.xlabel('incident_type')
plt.ylabel('vehicle_claim')
plt.title('WHICH incident_type HAS MORE vehicle_claim AMOUNT')
plt.show()

# %% [markdown]
# ***OBSERVATION FROM ABOVE:***
#     1. AS WE CAN SEE IT IS SAME AS TOTAL AMOUNT CLAIMED WITH INCIDENT TYPE
#     2.  FOR SINGLE AND MULTI VEHICLE AMOUNT IS MORE CLAIMED COMPARED TO THEFT AND PART TYPE

# %%
data=dataset.copy()
data['incident_type'].hist(bins=25)
plt.xlabel('incident_type')
plt.ylabel("Count")
plt.title('incident_type')
plt.show()

# %% [markdown]
# ***OBSERVATIONS FROM ABOVE:***
#     1. THERE ARE MANY INCIDENTS HAPPENED WITH MORE COUNT IN SINGLE AND MULTIPLE
#     2. AND NEXT VEHICLE THEFT
#     3. LASTLY VEHICLE PARKED
